# %% [markdown]
# <a href="https://colab.research.google.com/github/pathipol/mushroom/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import string 
import numpy as np
import pickle
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import mutual_info_score
import pandas as pd
import numpy as np
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
url = 'https://raw.githubusercontent.com/nanphipat1999/dataset/main/find-kmitl_final.csv'
df = pd.read_csv(url)
df.columns
df = df.dropna()
df
# Out:
#     Gender                Program  ...    act8                   Faculties
# 0      ชาย             วิทย์-คณิต  ...  ไม่เคย          อุตสาหกรรมการเกษตร
# 1     หญิง             วิทย์-คณิต  ...  ไม่เคย                 วิทยาศาสตร์
# 2     หญิง             วิทย์-คณิต  ...  ไม่เคย                 วิทยาศาสตร์
# 3     หญิง             วิทย์-คณิต  ...  ไม่เคย          อุตสาหกรรมการเกษตร
# 4     หญิง             วิทย์-คณิต  ...  ไม่เคย          อุตสาหกรรมการเกษตร
# 5     หญิง             วิทย์-คณิต  ...  ไม่เคย                 วิทยาศาสตร์
# 6      ชาย             วิทย์-คณิต  ...  ไม่เคย                 วิทยาศาสตร์
# 7      ชาย             วิทย์-คณิต  ...  ไม่เคย                 วิทยาศาสตร์
# 8      ชาย             วิทย์-คณิต  ...  ไม่เคย                 วิทยาศาสตร์
# 9      ชาย  โครงการห้องเรียนพิเศษ  ...     เคย                 วิทยาศาสตร์
# 10     ชาย             วิทย์-คณิต  ...  ไม่เคย                 วิทยาศาสตร์
# ...

# %%
df['Gender'].replace(["ชาย", "หญิง"], [1,2],inplace=True)
df['Program'].replace(["โครงการห้องเรียนพิเศษ", "วิทย์-คณิต", "ศิลป์-คำนวณ", "ศิลป์-ภาษา", "ศิลป์-ทั่วไป"], [1, 2,3,4,5],inplace=True)
df['Entrance'].replace(["สอบเข้าระบบ tcas , admission , รับตรง", "โครงการพิเศษ"], [1,2],inplace=True)
df['GPA'].replace(["2.01 - 2.50", "2.51 - 3.00", "3.01 - 3.50", "3.51 - 4.00"], [1,2,3,4],inplace=True)
df['Thai'].replace(["0 - 20.00", "20.01 - 40.00", "40.01 - 60.00", "60.01 - 80.00", "80.01 - 100"], [1,2,3,4,5],inplace=True)
df['Math'].replace(["0 - 20.00", "20.01 - 40.00", "40.01 - 60.00", "60.01 - 80.00", "80.01 - 100"], [1,2,3,4,5],inplace=True)
df['Sci'].replace(["0 - 20.00", "20.01 - 40.00", "40.01 - 60.00", "60.01 - 80.00", "80.01 - 100"], [1,2,3,4,5],inplace=True)
df['Social'].replace(["0 - 20.00", "20.01 - 40.00", "40.01 - 60.00", "60.01 - 80.00", "80.01 - 100"], [1,2,3,4,5],inplace=True)
df['Eng'].replace(["0 - 20.00", "20.01 - 40.00", "40.01 - 60.00", "60.01 - 80.00", "80.01 - 100"], [1,2,3,4,5],inplace=True)
df['Activityin'].replace(["เคยเข้าร่วม", "ไม่เคยเข้าร่วม"], [1,2],inplace=True)
df['Academically'].replace(["เคย", "ไม่เคย"], [1,2],inplace=True)
df['Faculties'].replace(["วิทยาศาสตร์", "วิศวกรรมศาสตร์", "อุตสาหกรรมการเกษตร", "สถาปัตยกรรมศาสตร์", "เทคโนโลยีสารสนเทศ", "วิทยาลัยการบริหารและจัดการ"], [1,2,3,4,5,6],inplace=True)
df['Abillity1'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity2'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity3'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity4'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity5'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity6'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity7'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity8'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity9'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity10'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity11'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Abillity12'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Subject1'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Subject3'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Subject2'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Subject4'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Subject5'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Subject6'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Subject7'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Subject8'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillg1'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillg2'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillg3'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillg4'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillg5'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillg6'].replace(["ไม่มี","มี"], [0,1],inplace=True)

df['Skillp1'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillp2'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillp3'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillp4'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillp5'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Skillp6'].replace(["ไม่มี","มี"], [0,1],inplace=True)

df['Interest1'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Interest2'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Interest3'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Interest4'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Interest5'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Interest6'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Interest7'].replace(["ไม่มี","มี"], [0,1],inplace=True)
df['Interest8'].replace(["ไม่มี","มี"], [0,1],inplace=True)

df['act1'].replace(["เคย", "ไม่เคย"], [1,0],inplace=True)
df['act2'].replace(["เคย", "ไม่เคย"], [1,0],inplace=True)
df['act3'].replace(["เคย", "ไม่เคย"], [1,0],inplace=True)
df['act4'].replace(["เคย", "ไม่เคย"], [1,0],inplace=True)
df['act5'].replace(["เคย", "ไม่เคย"], [1,0],inplace=True)
df['act6'].replace(["เคย", "ไม่เคย"], [1,0],inplace=True)
df['act7'].replace(["เคย", "ไม่เคย"], [1,0],inplace=True)
df['act8'].replace(["เคย", "ไม่เคย"], [1,0],inplace=True)

# %%
df
# Out:
#      Gender  Program  Entrance  GPA  Thai  ...  act5  act6  act7  act8  Faculties
# 0         1        2         1    3     3  ...     0     0     0     0          3
# 1         2        2         1    3     3  ...     0     0     0     0          1
# 2         2        2         1    3     4  ...     0     0     0     0          1
# 3         2        2         1    4     3  ...     0     0     0     0          3
# 4         2        2         1    2     3  ...     0     1     0     0          3
# 5         2        2         1    4     4  ...     0     1     0     0          1
# 6         1        2         1    3     4  ...     0     0     1     0          1
# 7         1        2         1    2     3  ...     0     0     1     0          1
# 8         1        2         1    4     3  ...     1     0     0     0          1
# 9         1        1         1    4     4  ...     0     1     0     1          1
# ...

# %%
X = df.iloc[:,:-1].copy()
y = df.iloc[:,-1].copy()
X
# Out:
#      Gender  Program  Entrance  GPA  Thai  ...  act4  act5  act6  act7  act8
# 0         1        2         1    3     3  ...     0     0     0     0     0
# 1         2        2         1    3     3  ...     0     0     0     0     0
# 2         2        2         1    3     4  ...     0     0     0     0     0
# 3         2        2         1    4     3  ...     0     0     0     0     0
# 4         2        2         1    2     3  ...     0     0     1     0     0
# 5         2        2         1    4     4  ...     0     0     1     0     0
# 6         1        2         1    3     4  ...     0     0     0     1     0
# 7         1        2         1    2     3  ...     0     0     0     1     0
# 8         1        2         1    4     3  ...     0     1     0     0     0
# 9         1        1         1    4     4  ...     0     0     1     0     1
# 10        1        2         1    4     5  ...     0     0     0     0     0
# ...

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=6)
sfs1 = SFS(knn, 
           k_features=58, 
           forward=True, 
           floating=False, 
           verbose=2,
           scoring='accuracy',
           cv=3)

sfs1 = sfs1.fit(X, y)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:    0.9s finished
#
# [2021-04-28 15:35:23] Features: 1/58 -- score: 0.40598290598290604[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:    0.9s finished
#
# [2021-04-28 15:35:24] Features: 2/58 -- score: 0.42735042735042733[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:    0.9s finished
#
# [2021-04-28 15:35:25] Features: 3/58 -- score: 0.452991452991453[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
sfs1.subsets_
# Out:
# {1: {'avg_score': 0.40598290598290604,
#   'cv_scores': array([0.41025641, 0.3974359 , 0.41025641]),
#   'feature_idx': (1,),
#   'feature_names': ('Program',)},
#  2: {'avg_score': 0.42735042735042733,
#   'cv_scores': array([0.37179487, 0.47435897, 0.43589744]),
#   'feature_idx': (1, 6),
#   'feature_names': ('Program', 'Sci')},
#  3: {'avg_score': 0.452991452991453,
#   'cv_scores': array([0.41025641, 0.43589744, 0.51282051]),
#   'feature_idx': (1, 6, 43),
#   'feature_names': ('Program', 'Sci', 'Interest3')},
#  4: {'avg_score': 0.45726495726495725,
#   'cv_scores': array([0.38461538, 0.48717949, 0.5       ]),
#   'feature_idx': (1, 6, 34, 43),
#   'feature_names': ('Program', 'Sci', 'Skillg6', 'Interest3')},
#  5: {'avg_score': 0.4871794871794872,
#   'cv_scores': array([0.41025641, 0.43589744, 0.61538462]),
#   'feature_idx': (1, 6, 28, 34, 43),
#   'feature_names': ('Program', 'Sci', 'Subject8', 'Skillg6', 'Interest3')},
#  6: {'avg_score': 0.4914529914529915,
# ...

# %%
rf = RandomForestClassifier(max_depth=2, random_state=0, n_estimators=100)

# %%
#28 0.512 28column
X = df.iloc[:,[0,1,2,3,6,8,9,10,16,18,19,21,23,24,28,34,36,39,40,42,43,46,47,48,49,55,57,58]]
X
# Out:
#      Gender  Program  Entrance  GPA  ...  Activityin  act5  act7  act8
# 0         1        2         1    3  ...           1     0     0     0
# 1         2        2         1    3  ...           1     0     0     0
# 2         2        2         1    3  ...           1     0     0     0
# 3         2        2         1    4  ...           1     0     0     0
# 4         2        2         1    2  ...           1     0     0     0
# 5         2        2         1    4  ...           1     0     0     0
# 6         1        2         1    3  ...           1     0     1     0
# 7         1        2         1    2  ...           2     0     1     0
# 8         1        2         1    4  ...           1     1     0     0
# 9         1        1         1    4  ...           1     0     0     1
# 10        1        2         1    4  ...           1     0     0     0
# 11        2        1         1    3  ...           1     0     1     0
# ...

# %%
scores = cross_val_score(rf, X, y, scoring='accuracy', cv=10, n_jobs=-1)
print(scores)
print('Accuracy: %.3f ' % (mean(scores)))
# Out:
# [0.41666667 0.45833333 0.41666667 0.375      0.34782609 0.43478261
#  0.47826087 0.43478261 0.39130435 0.43478261]
# Accuracy: 0.419

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=2, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)
